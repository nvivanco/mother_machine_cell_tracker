# %%
import os
import tifffile
from tifffile import imread
import concat_tifs as ct

# %%
directory = "/Users/adrianjuarez/Documents/Covert_lab/Images_Markus/DUMM_giTg068_baeS_100225/hyperstacked/drift_corrected/rotated/mm_channels/to_stitch"

for f in sorted(os.listdir(directory)):
    if f.endswith(".tif") or f.endswith(".tiff"):
        arr = imread(os.path.join(directory, f))
        print(f, arr.shape)
        break

# %%
combined = ct.concat_hyperstack_tifs("/Users/adrianjuarez/Documents/Covert_lab/Images_Markus/DUMM_CL008_giTG061_081225/hyperstacked/drift_corrected/rotated/mm_channels/to_stitch_araA", "/Users/adrianjuarez/Documents/Covert_lab/Images_Markus/DUMM_CL008_giTG061_081225/hyperstacked/drift_corrected/rotated/mm_channels/to_stitch_araA/combined_output.tif")
